# %%
import numpy as np
import pandas as pd
from sklearn.datasets import load_boston
from sklearn.model_selection import train_test_split
from XGBoost import XGBoost

# %%
boston = load_boston()
X, y = boston.data, boston.target
feature_name = boston.feature_names
# Out:
# /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages/sklearn/utils/deprecation.py:87: FutureWarning: Function load_boston is deprecated; `load_boston` is deprecated in 1.0 and will be removed in 1.2.
#
#     The Boston housing prices dataset has an ethical problem. You can refer to
#     the documentation of this function for further details.
#
#     The scikit-learn maintainers therefore strongly discourage the use of this
#     dataset unless the purpose of the code is to study and educate about
#     ethical issues in data science and machine learning.
#
#     In this case special case, you can fetch the dataset from the original
#     source::
#
#         import pandas as pd
#         import numpy as np
#
#
#         data_url = "http://lib.stat.cmu.edu/datasets/boston"
#         raw_df = pd.read_csv(data_url, sep="\s+", skiprows=22, header=None)
#         data = np.hstack([raw_df.values[::2, :], raw_df.values[1::2, :2]])
#         target = raw_df.values[1::2, 2]
#
#     Alternative datasets include the California housing dataset (i.e.
#     func:`~sklearn.datasets.fetch_california_housing`) and the Ames housing
#     dataset. You can load the datasets as follows:
#
#         from sklearn.datasets import fetch_california_housing
#         housing = fetch_california_housing()
#
#     for the California housing dataset and:
#
#         from sklearn.datasets import fetch_openml
#         housing = fetch_openml(name="house_prices", as_frame=True)
#
#     for the Ames housing dataset.
#
#   warnings.warn(msg, category=FutureWarning)

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, random_state=0)
X_train_df = pd.DataFrame(X_train, columns=feature_name)
y_train_df = pd.Series(y_train)

# %%
model = XGBoost(3,3)
model.fit(X_train_df, y_train_df)
# Out:
# ---------------------------------------------------------------------------
# UnboundLocalError                         Traceback (most recent call last)
# /var/folders/0p/g6nj5mqd3xl8lx0bpcg9f4nw0000gn/T/ipykernel_35202/472021095.py in <module>
#       1 model = XGBoost(3,3)
# ----> 2 model.fit(X_train_df, y_train_df)
#
# ~/Desktop/learn/TreeModel/XGBoost.py in fit(self, x_data, y_data)
#     152         for _ in range(self.n_estimators):
#     153             tree = XGBoostRegressionTree(self.max_depth, self.lambda_value, self.gamma)
# --> 154             tree.fit(x_data, y_data, prediction)
#     155             self.trees.append(tree)
#     156
#
# ~/Desktop/learn/TreeModel/XGBoost.py in fit(self, x_data, y_data, y_pred)
#     113                 if len(region) == 0:
#     114                    continue
# --> 115                 split_feature, split_value, left_value, right_value, left_region, right_region = self.split_region(x_data.loc[region], y_data.loc[region], features, gradient, hess)
#     116                 # 根据分裂结果，更新树模型
#     117                 left_node, right_node = father_node.split(split_feature, split_value,
#
# ~/Desktop/learn/TreeModel/XGBoost.py in split_region(self, x_data, y_data, features, gradient, hess)
#      80                     split_value = value
#      81                     left_value = left_value_temp
# ---> 82                     right_value = right_value_temp
#      83                     left_region = y_data[x_data[feature] < value].index
#      84                     right_region = y_data[x_data[feature] >= value].index
#
# UnboundLocalError: local variable 'right_value_temp' referenced before assignment

# %%
X_test_df = pd.DataFrame(X_test, columns=feature_name)
y_test_df = pd.Series(y_test)

# %%
y_pred = model.predict(X_test_df)

# %%
import matplotlib.pyplot as plt

plt.figure(figsize=(12,7))
plt.plot(X_test_df.index, y_test_df.values)
plt.plot(X_test_df.index, y_pred)

# %%
from sklearn import datasets  # 导入库

cancer = datasets.load_breast_cancer()
X, y = cancer.data, cancer.target
feature_name = cancer.feature_names

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, random_state=0)
X_train_df = pd.DataFrame(X_train, columns=feature_name)
y_train_df = pd.Series(y_train)
print(X_train_df.head(5))
print(y_train_df.head(5))
# Out:
#    mean radius  mean texture  mean perimeter  mean area  mean smoothness  \
# 0        10.05         17.53           64.41      310.8          0.10070
# 1        10.80         21.98           68.79      359.9          0.08801
# 2        16.14         14.86          104.30      800.0          0.09495
# 3        12.18         17.84           77.79      451.1          0.10450
# 4        12.25         22.44           78.18      466.5          0.08192
#
#    mean compactness  mean concavity  mean concave points  mean symmetry  \
# 0           0.07326         0.02511              0.01775         0.1890
# 1           0.05743         0.03614              0.01404         0.2016
# 2           0.08501         0.05500              0.04528         0.1735
# 3           0.07057         0.02490              0.02941         0.1900
# 4           0.05200         0.01714              0.01261         0.1544
#
#    mean fractal dimension  ...  worst radius  worst texture  worst perimeter  \
# 0                 0.06331  ...         11.16          26.84            71.98
# 1                 0.05977  ...         12.76          32.04            83.69
# 2                 0.05875  ...         17.71          19.58           115.90
# 3                 0.06635  ...         12.83          20.92            82.14
# 4                 0.05976  ...         14.17          31.99            92.74
#
#    worst area  worst smoothness  worst compactness  worst concavity  \
# 0       384.0            0.1402            0.14020           0.1055
# 1       489.5            0.1303            0.16960           0.1927
# 2       947.9            0.1206            0.17220           0.2310
# 3       495.2            0.1140            0.09358           0.0498
# 4       622.9            0.1256            0.18040           0.1230
#
#    worst concave points  worst symmetry  worst fractal dimension
# 0               0.06499          0.2894                  0.07664
# 1               0.07485          0.2965                  0.07662
# 2               0.11290          0.2778                  0.07012
# 3               0.05882          0.2227                  0.07376
# 4               0.06335          0.3100                  0.08203
#
# [5 rows x 30 columns]
# 0    1
# 1    1
# 2    1
# 3    1
# 4    1
# dtype: int64
